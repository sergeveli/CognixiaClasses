# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
path = '/Users/veli/Desktop/DataEngineering/W3D3/archive/csv/common_player_info.csv'
df = pd.read_csv(path)

# %%
df.head(13)
# Out:
#     person_id first_name    last_name  display_first_last  \
# 0          51    Mahmoud   Abdul-Rauf  Mahmoud Abdul-Rauf
# 1        1505      Tariq  Abdul-Wahad   Tariq Abdul-Wahad
# 2       76007       John    Abramovic      John Abramovic
# 3      203112     Quincy          Acy          Quincy Acy
# 4      200801     Hassan        Adams        Hassan Adams
# 5      203919     Jordan        Adams        Jordan Adams
# 6         912     Rafael      Addison      Rafael Addison
# 7      201336      Blake       Ahearn        Blake Ahearn
# 8      202374    Solomon        Alabi       Solomon Alabi
# 9       76019       Mark       Alarie         Mark Alarie
# 10     203128     Furkan      Aldemir      Furkan Aldemir
# 11     200746   LaMarcus     Aldridge   LaMarcus Aldridge
# 12    1626146      Cliff    Alexander     Cliff Alexander
#
#    display_last_comma_first display_fi_last         player_slug  \
# 0       Abdul-Rauf, Mahmoud   M. Abdul-Rauf  mahmoud-abdul-rauf
# ...

# %%
sns.scatterplot(x='weight', y='height', data=df)
# Out:
# <Axes: xlabel='weight', ylabel='height'>
